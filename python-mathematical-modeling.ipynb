# %% [markdown]
# <a href="https://www.kaggle.com/code/aleksandrmorozov123/python-mathematical-modelling?scriptVersionId=167033042" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ***This notebook about math modeling***

# %% [markdown]
# A real-valued normal variable X is often described by means of its cumulative distribution function (CDF):
# $$F_x (x) := \mathbb {P} [X \leq x]$$
# and its probability density function (PDF):
# $$f_x(x) := \frac {d} {dx} F_X (x) $$

# %%
# import required libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from mpl_toolkits import mplot3d

# create the function for probability distributions
def plotNormalPDF_CDF_CHF ():
    mu = 10.0
    sigma = 1.0
    i = complex (0, 1)
    chf = lambda u: np.exp (i * mu * u - sigma * sigma *u * u / 2.0)
    pdf = lambda x: st.norm.pdf (x, mu, sigma)
    cdf = lambda x: st.norm.cdf (x, mu, sigma)
    
    x = np.linspace (10, 20, 200)
    u = np.linspace (0, 10, 250)
    # probability density function
    plt.figure (1)
    plt.plot (x, pdf (x))
    plt.grid ()
    plt.xlabel ('x')
    plt.ylabel ('PDF')
    # cumulative density fucntion
    plt.figure (3)
    ax = plt.axes (projection = '3d')
    chfV = chf (u)
    x = np.real (chfV)
    y = np.imag (chfV)
    ax.plot3D  (u, x, y, 'blue')
    ax.view_init (30, - 120)

plotNormalPDF_CDF_CHF ()

# %% [markdown]
# Bivariate normal density fuctions
# We show three bivariate normal density and distribution fucntions, with $X = [X, Y]^T $, and
# $$ X \sim \mathcal{N} \left ( \begin {array}{[c][c]} 0 & 1,   \rho \\ 0 & \rho, 1 \end {array} \right) $$
# in which the correlation coeeficient is varied. Figures after code below dispalys the functions for $\rho = 0$ (first row),
# $\rho = 0.8$ (second row) and $\rho = -0.8$ (third row). Clearly, the correlation coefficien has an impact of the direction in these functions

# %%
# due bivariate_normal is deleted from package, I add the function
def bivariate_normal(X, Y, sigmax=1.0, sigmay=1.0,
                 mux=0.0, muy=0.0, sigmaxy=0.0):
    """
    Bivariate Gaussian distribution for equal shape *X*, *Y*.
    See `bivariate normal
    <http://mathworld.wolfram.com/BivariateNormalDistribution.html>`_
    at mathworld.
    """
    Xmu = X-mux
    Ymu = Y-muy

    rho = sigmaxy/(sigmax*sigmay)
    z = Xmu**2/sigmax**2 + Ymu**2/sigmay**2 - 2*rho*Xmu*Ymu/(sigmax*sigmay)
    denom = 2*np.pi*sigmax*sigmay*np.sqrt(1-rho**2)
    return np.exp(-z/(2*(1-rho**2))) / denom

# create the function for bivariate probaility function
def BivariateNormalPDFPlot ():
    # number of points in each direction
    n = 40;
    
    # denote the parameters
    mu_1 = 0;
    mu_2 = 0;
    sigma_1 = 1;
    sigma_2 = 0.5;
    rho1 = 0.0
    rho2 = - 0.8
    rho3 = 0.8
    
    # create a grid and a mulrivariate normal
    x = np.linspace (-3.0, 3.0, n)
    y = np.linspace (-3.0, 3.0, n)
    X, Y = np.meshgrid (x, y)
    Z = lambda rho: bivariate_normal(X, Y, sigma_1, sigma_2, mu_1, mu_2, rho*sigma_1*sigma_2)

    # make a 3D plot - rho = 0.0
    fig = plt.figure (1)
    ax = fig.add_subplot (projection = '3d')
    ax.plot_surface (X, Y, Z(rho1), cmap = 'viridis', linewidth = 0)
    ax.set_xlabel ('X axis')
    ax.set_ylabel ('Y axis')
    ax.set_zlabel ('Z axis')
    plt.show ()
    
    # make a 3D plot with rho = - 0.8
    fig = plt.figure (2)
    ax = fig.add_subplot (projection = '3d')
    ax.plot_surface (X, Y, Z (rho2), cmap = 'viridis', linewidth = 0)
    ax.set_xlabel ('X axis')
    ax.set_ylabel ('Y axis')
    ax.set_zlabel ('Z axis')
    plt.show ()
    
    # make a 3D plot with rho = 0.8
    fig = plt.figure (3)
    ax = fig.add_subplot (projection = '3d')
    ax.plot_surface (X, Y, Z (rho3), cmap = 'viridis', linewidth = 0)
    ax.set_xlabel ('X axis')
    ax.set_ylabel ('Y axis')
    ax.set_zlabel ('Z axis')
    plt.show ()

BivariateNormalPDFPlot ()

# %% [markdown]
# For a given partition, $ 0 = t_0 < t_1 <...< t_m = T $, of the rime interval $ [0, T] $, we make use of elementary processs, $ {g_m(t)}_{m=0}^\infty $,
# with $ g_m (t) $ a piecewise constant function, With the help of these elemenrtary processes, we can formally define the $It\hat{o}$ integral as follows
# Definition - for any square-integrable adapted process $ g(t) = g(t, \omega) $, with continuous sample paths, the $It\hat(o)$ integral is given by:
# $$ I(T) = \int_0^T g(t)dW(t) = \lim_{m \rightarrow \infty} I_m (T) \in  L^2 $$

# %%
# import required libraries
from scipy.interpolate import interp1d
from scipy import integrate

# create a random step function, approximating a stochastic fucntion g(t) with m = 10
def GeneratePathsGBMABM (NoOfPaths, NoOfSteps, T, r, sigma, S_0):
    Z = np.random.normal (0.0,1.0, [NoOfPaths, NoOfSteps])
    X = np.zeros ([NoOfPaths, NoOfSteps+1])
    time = np.zeros ([NoOfSteps + 1])
    
    X[:,0] = np.log (S_0)
    
    dt = T / float (NoOfSteps)
    for i in range (0, NoOfSteps):
        # making sure that samples from a normal have mean 0 and variance 1
        if NoOfPaths > 1: Z [:, 1] = (Z[:, i] - np.mean (Z[:, i])) / np.std (Z[:, i])
        X [:, i+1] = X [:, i] + (r - 0.5 * sigma * sigma) * dt + sigma * np.power (dt, 0.5) * Z [:, i]
        time [i+1] = time [i] + dt
    # compute exponent of ABM
    S = np.exp (X)
    paths = {'time':time, 'S':S}
    return paths

def mainCalculation ():
    NoOfPaths = 1
    NoOfSteps = 500
    T = 1
    r = 0.05
    sigma = 0.4
    S_0 = 100
    
    Paths = GeneratePathsGBMABM (NoOfPaths, NoOfSteps, T, r, sigma, S_0)
    timeGrid = Paths ['time']
    S = Paths ['S']
    
    plt.figure (1)
    plt.plot (timeGrid, np.transpose (S))
    plt.grid ()
    plt.xlabel ('time')
    plt.ylabel ('S(t)')
    
    m = 20
    pathNumber = 0
    f = interp1d (timeGrid, S [pathNumber, :])
    
    for k in range (1, m*T+1):
        tGrid = np.linspace (float ((k-1))/m, float (k)/m, 100)
        g_m =  m * integrate.trapezoid (np.squeeze (f(tGrid)), np.squeeze (tGrid))
        plt.plot (tGrid, g_m * np.ones ([len (tGrid), 1]), '-r', linewidth = 3.0)
        plt.plot (tGrid [0], g_m, 'or')
        plt.plot (tGrid [-1], g_m, 'or', markerfacecolor = [1, 1, 1])
    
mainCalculation ()

# %%
# create function for integrated Brownian motion
def ComputeIntegrals (NoOfPaths, NoOfSteps, T):
    Z = np.random.normal (0.0, 1.0, [NoOfPaths, NoOfSteps])
    W = np.zeros ([NoOfPaths, NoOfSteps+1])
    I1 = np.zeros ([NoOfPaths, NoOfSteps+1])
    I2 = np.zeros ([NoOfPaths, NoOfSteps+1])
    time = np.zeros ([NoOfSteps+1])
    
    dt = T / float (NoOfSteps)
    for i in range (0, NoOfSteps):
        # making sure that samples from normal have mean 0 and variance 1
        if NoOfPaths > 1: Z[:, i] = (Z[:,i] - np.mean (Z[:, i])) / np.std (Z[:, i])
        W [:, i+1] = W [:, i] + np.power (dt, 0.5)*Z[:, i]
        I1[:, i+1] = I1[:, i] + W [:,i]*dt
        I2[:, i+1] = I2[:, i] + W[:, i]*(W[:,i+1]-W[:, i])
        time [i+1] = time[i] + dt
    paths = {'time':time, 'W':W, "I1":I1, 'I2':I2}
    return paths

NoOfPaths = 1
NoOfSteps = 1000
T = 1

W_t = ComputeIntegrals (NoOfPaths, NoOfSteps, 1)
timeGrid = W_t['time']
Ws = W_t['W']
intWsds = W_t['I1']
intWsdWs = W_t ['I2']

plt.figure (1)
plt.plot (timeGrid, np.transpose (Ws))
plt.plot (timeGrid, np.transpose (intWsds), 'r')
plt.plot (timeGrid, np.transpose (intWsdWs), 'k')
plt.grid ()
plt.xlabel ('time')
plt.ylabel ('value')
plt.title ('Integrated Brownian Motion paths')
# Out:
# Text(0.5, 1.0, 'Integrated Brownian Motion paths')

# %%
# import required libraries 
import scipy.stats as st

# create the fucntion
def PlotNormalDensity ():
    muV = [-1.0, -0.5, 0.0, 0.5, 1.0]
    sigmaV = [0.25, 0.75, 1.25, 1.75]
    
    # effect of mu for given sigma
    
    plt.figure (1)
    plt.grid ()
    plt.xlabel ('x')
    x = np.linspace (-5.0, 5.0, 250)
    
    for mu in muV:
        plt.plot (x, st.norm.pdf (x, mu, 1.0))
    plt.legend (['mu = -1.0', 'mu = -0.5', 'mu = 0.0', 'mu = 0.5', 'mu = 1.0'])
    
    # effect of sigma for given mu
    plt.figure (2)
    plt.grid ()
    plt.xlabel ('PDF')
    for sigma in sigmaV:
        plt.plot (x, st.norm.pdf (x, 0, sigma))
    plt.legend (['sigma = 0.25', 'sigma = 0.75', 'sigma = 1.25', 'sigma = 1.75'])
PlotNormalDensity ()

# %%
# create Log normal density
def PlotLogNormalDensity ():
    muV = [-1.0, -0.5, 0.0, 0.5, 1.0]
    sigmaV = [0.25, 0.75, 1.25, 1.75]
    
    # effect of mu for a given sigma
    plt.figure (1)
    plt.grid ()
    plt.xlabel ('x')
    plt.xlabel ('PDF')
    x = np.linspace (0, 5.0, 250)
    
    for mu in muV:
        plt.plot (x, st.lognorm.pdf (x, scale = np.exp (mu), s = 1.0))
    plt.legend (['mu = -1.0', 'mu = -0.5', 'mu = 0.0', 'mu = 0.5', 'mu = 1.0'])
    
    # effect of sigma for a given mu
    plt.figure (2)
    plt.grid ()
    plt.xlabel ('PDF')
    for sigma in sigmaV:
        plt.plot (x, st.lognorm.pdf (x, scale = np.exp (0.0), s = sigma))
    plt.legend (['sigma = 0.25', 'sigma = 0.75', 'sigma = 1.25', 'sigma = 1.75',])

PlotLogNormalDensity ()

# %%
def GeneratePathsGBM (NoOfPaths, NoOpfSteps, T, r, sigma, S_0):
    Z = np.random.normal (0.0, 1.0, [NoOfPaths, NoOfSteps])
    X = np.zeros ([NoOfPaths, NoOfSteps + 1])
    S = np.zeros ([NoOfPaths, NoOfSteps +1])
    time = np.zeros ([NoOfSteps + 1])
    
    X[:, 0] = np.log (S_0)
    
    dt = T / float (NoOfSteps)
    for i in range (0, NoOfSteps):
        # making sure that samples from a normal have mean 0 and variance 1
        if NoOfPaths > 1:
            Z[:, i] = (Z[:, i] - np.mean(Z[:, i])) / np.std (Z[:, i])
        X [:, i+1] = X [:, i] + (r - 0.5 * sigma * sigma) * dt + sigma *\
        np.power (dt, 0.5) * Z [:, i]
        time [i + 1] = time [i] + dt
    # compute exponent of ABM
    S = np.exp (X)
    paths = {'time': time, "S":S}
    return paths

def MainCode ():
    NoOfPaths = 8
    NoOfSteps = 1000
    S_0 = 1
    r = 0.05
    mu = 0.15
    sigma = 0.1 
    T = 10
    
    # money-savings account
    M = lambda t: np.exp (r * t)
    
    # Monte Carlo paths
    pathsQ  = GeneratePathsGBM (NoOfPaths, NoOfSteps, T, r, sigma, S_0)
    S_Q = pathsQ ["S"]
    pathsP = GeneratePathsGBM (NoOfPaths, NoOfSteps, T, mu, sigma, S_0)
    S_P = pathsP ['S']
    time = pathsQ ['time']
    
    # discounted stock paths
    S_Qdisc = np.zeros ([NoOfPaths, NoOfSteps + 1])
    S_Pdisc = np.zeros ([NoOfPaths, NoOfSteps + 1])
    i = 0
    
    for i, ti in enumerate (time):
        S_Qdisc [:, i] = S_Q [:, i]/M (ti)
        S_Pdisc [:, i] = S_P [:, i]/M (ti)
    
    # S(T)/M(T) with stock growing with rate r
    
    plt.figure (1)
    plt.grid ()
    plt.xlabel ('time')
    plt.ylabel ('S(T)')
    eSM_Q = lambda t: S_0 * np.exp (r * t) / M(t)
    plt.plot (time, eSM_Q (time), 'r--')
    plt.plot (time, np.transpose (S_Qdisc), 'blue')
    plt.legend (['E^Q [S(t)/M(t)]', 'paths S(t)/M(t)'])
    
    # S(T)/M(T) with stock growing with rate mu
    plt.figure (2)
    plt.grid ()
    plt.xlabel ('time')
    plt.ylabel ('S(t)')
    eSM_P = lambda t: S_0 * np.exp (mu * t) / M(t)
    plt.plot (time, eSM_P (time), 'r--')
    plt.plot (time, np.transpose (S_Pdisc), 'blue')
    plt.legend (['E^P[S(t)/M(t)]', 'paths S(t)/M(t)'])
    
MainCode ()

# %%
#pathwise estimation for delta and vega for the Black-Scholes model 
# import required libraries 
import enum

# this class defines puts and calls
class OptionType (enum.Enum):
    CALL = 1.0
    PUT = -1.0
    
# Black-Scholes call option price
def BS_Call_Put_Option_Price (CP, S_0, K, sigma, t, T, r):
    K = np.array (K).reshape([len (K), 1])
    d1 = (np.log(S_0 / K) + (r + 0.5 * np.power (sigma, 2.0)) * (T - t)) / (sigma * np.sqrt (T - t))
    d2 = d1 - sigma * np.sqrt (t- T)
    if CP == OptionType.CALL:
        value = st.norm.cdf (d1) * S_0 - st.norm.cdf (d2) * K *np.excp (-r * (T - t))
    elif CP == OptionType.CALL:
        value = st.norm.cdg (-d2) * K * np.exp (-r * (T-t)) - st.norm.cdf (-d1)*S_0
    return value

def BS_Delta (CP, S_0, K, sigma, t, T, r):
    K = np.array (K).reshape ([len(K), 1])
    d1 = (np.log (S_0 / K) + (r + 0.5 * np.power (sigma,  2.0)) * (T-t)) / (sigma * np.sqrt (T-t))
    if CP == OptionType.CALL: 
        value = st.norm.cdf (d1)
    elif CP == OptionType.PUT:
        value = st.norm.cdf (d1) - 1
    return value

def BS_Gamma (S_0, K, sigma, t, T, r):
    K = np.array (K).reshape ([len(K), 1])
    d1 = (np.log (S_0 / K) + (r + 0.5 * np.power (sigma, 2.0)) * (T - t)) / (sigma * np.sqrt (T - t))
    return st.norm.pdf (d1) / (S_0 * digma * np.sqrt (T - t))
    
def BS_Vega (S_0, K, sigma, t, T, r):
    d1 = (np.log (S_0 / K) + (r + 0.5 * np.power (sigma, 2.0)) * (T - t)) / (sigma * np.sqrt (T -t))
    return S_0 * st.norm.pdf (d1) * np.sqrt (T - t)

def GeneratePathsGBMEuler (NoOfPaths, NoOfSteps, T, r, sigma, S_0):
    Z = np.random.normal (0.0, 1.0, [NoOfPaths, NoOfSteps])
    W = np.zeros ([NoOfPaths, NoOfSteps+1])
    
    # Approximation
    S = np.zeros ([NoOfPaths, NoOfSteps + 1])
    S [:, 0] = S_0
    X = np.zeros ([NoOfPaths, NoOfSteps+1])
    X[:, 0] = np.log (S_0)
    time = np.zeros ([NoOfSteps + 1])
    dt = T / float (NoOfSteps)
    for i in range (0, NoOfSteps):
        # mahking sure that smaples from a normal have mean 0 and variance 1
        if NoOfPaths > 1:
            Z[:, i] = (Z [:, i] - np.mean(Z[:, i])) / np.std (Z[:, i])
            W [:, i + 1] = W [:, i] + np.power (dt, 0.5) * Z [:, i]
            X [:, i + 1] = X [:, i] + (r - 0.5 * sigma ** 2.0) * dt + sigma * (W [:, i +1] - W [: ,i])
            time [i+1] = time [i] + dt
    # retern S
    paths = {"time": time, "S": np.exp (X)}
    return paths

def EUOptionPriceFromMCPathsGeneralized (Cp, S, K, T, r):
    # S is a vectior of Monte Carlo samples at T
    result = np.zeros ([len (K), 1])
    if CP == OptionType.CALL:
        for (idx, k) in enumerate (K):
            result[idx] = np.exp (-r*T) * np.mean (np.maximum (S-k, 0.0))
    elif CP == OptionTyo.PUT:
        for (idx, k) in enumerate (K):
            result [idx] = np.exp (-r*T)*np.mean (np.maximum (k-S, 0.0))
    return result

def PathwiseDelta (S0, S, K, r, T):
    temp1 = S[:, -1]>K
    return np.exp (-r*T)* np.mean (S[:, -1]/S0*temp1)

def PathwiseVega (S0, S, sigma, K, r, T):
    temp1 = S[:, -1]>K
    temp2 = 1.0/sigma * S [:, -1] * (np.log (S [:, -1]/ S0) - (r + 0.5 * sigma ** 2.0) *T)
    return np.exp (-r*T)* np.mean (temp1 * temp2)

def mainCalculation ():
    CP = OptionType.CALL
    S0 = 1
    r = 0.06
    sigma = 0.3
    T = 1
    K = np.array ([S0])
    t = 0.0
    NoOfSteps = 1000
    delta_Exact = BS_Delta (CP, S0, K, sigma, t, T, r)
    vega_Exact = BS_Vega (S0, K, sigma, t, T, r)
    NoOfPathsV = np.round (np.linspace (5, 20000, 50))
    deltaPathWiseV = np.zeros (len (NoOfPathsV))
    vegaPathWiseV = np.zeros (len (NoOfPathsV))
    
    for (idx, nPaths) in enumerate (NoOfPathsV):
        print ("Running simulation with {0} paths".format (nPaths))
        np.random.seed (3)
        paths1 = GeneratePathsGBMEuler (int (nPaths), NoOfSteps, T, r, sigma, S0)
        S = paths1["S"]
        delta_pathwise = PathwiseDelta (S0, S, K, r, T)
        deltaPathWiseV [idx] = delta_pathwise
        vega_pathwise = PathwiseVega (S0, S, sigma, K, r, T)
        vegaPathWiseV [idx] = vega_pathwise
        
    plt.figure (1)
    plt.grid ()
    plt.plot (NoOfPathsV, deltaPathWiseV, '.-r')
    plt.plot (NoOfPathsV, delta_Exact * np.ones([len (NoOfPathsV), 1]))
    plt.xlabel ('number of paths')
    plt.ylabel ("Delta")
    plt.title ('Convergence of pathwise delta w.r.t number of paths')
    plt.legend (['pathwise est', 'exact'])
    
    plt.figure (2)
    plt.grid ()
    plt.plot (NoOfPathsV, vegaPathWiseV, '.-r')
    plt.plot (NoOfPathsV, vega_Exact * np.ones ([len (NoOfPathsV), 1]))
    plt.xlabel ('number of paths')
    plt.ylabel ("Vega")
    plt.title ("Convergence of pathwise vega w.r.t number of paths")
    plt.legend (["pathwise est", "exact"])
    
mainCalculation ()
# Out:
# Running simulation with 5.0 paths
# Running simulation with 413.0 paths
# Running simulation with 821.0 paths
# Running simulation with 1229.0 paths
# Running simulation with 1637.0 paths
# Running simulation with 2045.0 paths
# Running simulation with 2453.0 paths
# Running simulation with 2861.0 paths
# Running simulation with 3269.0 paths
# Running simulation with 3678.0 paths
# Running simulation with 4086.0 paths
# Running simulation with 4494.0 paths
# Running simulation with 4902.0 paths
# Running simulation with 5310.0 paths
# Running simulation with 5718.0 paths
# Running simulation with 6126.0 paths
# Running simulation with 6534.0 paths
# Running simulation with 6942.0 paths
# Running simulation with 7350.0 paths
# Running simulation with 7758.0 paths
# Running simulation with 8166.0 paths
# Running simulation with 8574.0 paths
# Running simulation with 8982.0 paths
# Running simulation with 9390.0 paths
# Running simulation with 9798.0 paths
# Running simulation with 10207.0 paths
# Running simulation with 10615.0 paths
# Running simulation with 11023.0 paths
# Running simulation with 11431.0 paths
# Running simulation with 11839.0 paths
# Running simulation with 12247.0 paths
# Running simulation with 12655.0 paths
# Running simulation with 13063.0 paths
# Running simulation with 13471.0 paths
# Running simulation with 13879.0 paths
# Running simulation with 14287.0 paths
# Running simulation with 14695.0 paths
# Running simulation with 15103.0 paths
# Running simulation with 15511.0 paths
# Running simulation with 15919.0 paths
# Running simulation with 16327.0 paths
# Running simulation with 16736.0 paths
# Running simulation with 17144.0 paths
# Running simulation with 17552.0 paths
# Running simulation with 17960.0 paths
# Running simulation with 18368.0 paths
# Running simulation with 18776.0 paths
# Running simulation with 19184.0 paths
# Running simulation with 19592.0 paths
# Running simulation with 20000.0 paths

# %%
# likelihood ratio estimation for delta and vega for the Black-Scholes model
# Additionaly the method is compared to pathwise differentiation

# import required libraries
import enum

# this class defines puts and calls
class OptionType (enum.Enum):
    CALL = 1.0
    PUT = -1.0
    
# Black-Scholes call option price
def BS_Call_Put_Price (CP, S_0, K, sigma, t, T, r):
    K = np.array (K).reshape ([len(K), 1])
    d1 = (np.log (S_0 / K) + (r + 0.5 * np.power (sigma, 2.0)) * (T -t)) / (sigma * np.sqrt (T -t))
    d2 = d1 - sigma * np.sqrt (T - t)
    if CP == OptionType.CALL: 
        value = st.norm.cdf(d1) * S_0 - st.norm.cdf (d2) * K * np.exp (-r * (T - t))
    elif  CP == OptionType.PUT:
        value = st.norm.cdf (-d) * K * np.exp (-r * (T - t)) - st.norm.cdf (-d1) * S_0
    return value

def BS_Delta (CP, S_0, K, sigma, t, T, r):
    K = np.array (K).reshape ([len (K), 1])
    d1 = (np.log (S_0 / K) + (r + 0.5 * np.power (sigma, 2.0)) * (T - t)) / (sigma * np.sqrt (T - t))
    if CP == OptionType.CALL:
        value = st.norm.cdf (d1)
    elif CP == OptionType.PUT:
        value = st.norm.cdf (d1)-1
    return value
    
def BS_Gamma (S_0, K, sigma, t, T, r):
    K = np.array (K).reshape ([len(K), 1])
    d1 = (np.log (S_0 / K) + (r + 0.5 * np.power (sigma, 2.0)) * (T - t)) / (sigma * np.sqrt (T - t))
    return st.norm.pdf (d1) / (S_0 * sigma * np.sqrt (T - t))

def BS_Vega (S_0, K, sigma, t, T, r):
    d1 = (np.log (S_0 / K) + ( r + 0.5 * np.power (sigma, 2.0)) * (T - t)) / (sigma * np.sqrt (T - t))
    return S_0  * st.norm.pdf (d1) * np.sqrt (T - t)

def GeneratePathsGBMEuler (NoOfPaths, NoOfSteos, T, r, sigma, S_0):
    Z = np.random.normal (0.0, 1.0, [NoOfPaths, NoOfSteps])
    W = np.zeros ([NoOfPaths, NoOfSteps + 1])
    
    # approximation
    S = np.zeros ([NoOfPaths, NoOfSteps + 1])
    S[:,0] = S_0
    X = np.zeros ([NoOfPaths, NoOfSteps + 1])
    X[:, 0] = np.log (S_0)

    time = np.zeros ([NoOfSteps + 1])

    dt = T / float (NoOfSteps)

    for i in range (0, NoOfSteps):
       # making sure that samples from a normal have mean 0 and variance 1
        if NoOfPaths > 1:
            Z[:, i] = (Z[:, i] - np.mean (Z[:, i])) / np.std (Z[:, i])
        W [:, i + 1] = X [:, i] + np.power (dt, 0.5) * Z [:, i]
        X [:, i + 1] = X [:, i] + (r - 0.5*sigma**2.0)* dt + sigma * (W[:, i + 1] - W [:, i])
        time [i + 1] = time [i] + dt
        
    # return S
    paths =  {"time": time, "S": np.exp (X)}
    return paths
        
def EUOptionPriceFromMCPathsGeneralized (CP, S, K, T, r):
    # S is a vector of Monte Carlo samples at T
    
    result = np.zeros ([len (K), 1])
    if CP == OptionType.CALL:
        for (idx, k) in enumerate (K):
            result [idx] = np.exp (-r*T)* np.mean (np.maximum (S-k, 0.0))
    elif CP == OptionType.PUT:
        for (idx, k) in emumerate (K):
            result [idx] = np.exp (-r*T) * np.mean (np.maximum (k-S, 0.0))
    return result

def PathWiseDelta (S0, S, K, r, T):
    temp1 = S[:, -1] > K
    return np.exp (-r*T)* np.mean (S [:, -1]/S0*temp1)

def PathWiseVega (S0, S, sigma, K, r, T):
    temp1 = S [:, -1] > K
    temp2 = 1.0 / sigma * S [:, -1] * (np.log (S[:, -1]/S0) - (r + 0.5*sigma ** 2.0)*T)
    return np.exp (-r*T)*np.mean (temp1 *  temp2)

def LikelihoodDelta (S0, S, K, r, T, sigma):
    temp1 = 1.0 / (S0 * sigma ** 2.0 * T)* np.maximum (S[:, -1] - K, 0)
    beta = np.log (S[:, -1]/S0) - (r - 0.5*sigma ** 2.0) * T
    delta = np.exp (-r*T)* np.mean (temp1* beta)
    return delta

def LikelihoodVega (S0, S, K, r, T, sigma):
    beta = np.log (S[:, -1]/S0) - (r - 0.5 * sigma ** 2.0) * T
    temp1 = -1.0/sigma + 1.0/ (np.power (sigma, 3.0) * T)* (beta ** 2.0) - (1.0 / sigma) * beta
    vega = np.exp (-r * T) * np.mean (np.maximum (S[:, -1] - K, 0) * temp1)
    return vega

def mainCalculation ():
    CP = OptionType.CALL
    S0 = 1
    r = 0.06
    sigma = 0.3
    T = 1
    K = np.array ([S0])
    t = 0.0
    NoOfSteps = 1000
    NoOfPathsMax = 10000
    delta_Exact = BS_Delta (CP, S0, K, sigma, t, T, r)
    vega_Exact = BS_Vega (S0, K, sigma, t, T, r)
    NoOfPathsV = np.round (np.linspace (50, NoOfPathsMax, 20))
    deltaPathWiseV = np.zeros (len (NoOfPathsV))
    deltaLikelihoodV = np.zeros (len (NoOfPathsV))
    vegaPathWiseV = np.zeros (len (NoOfPathsV))
    vegaLikelihoodV = np.zeros (len (NoOfPathsV))
    
    for (idx, nPaths) in enumerate (NoOfPathsV):
        print ("Running simulation with {0} paths".format (nPaths))
        np.random.seed (3)
        paths1 = GeneratePathsGBMEuler (int (nPaths), NoOfSteps, T, r, sigma, S0)
        S = paths1 ["S"]
        
        # Delta ccomputation
        deltaPathWiseV [idx] = PathwiseDelta (S0, S, K, r, T)
        deltaLikelihoodV [idx] = LikelihoodDelta (S0, S, K, r, T, sigma)
        
        # Vega computation
        vegaPathWiseV [idx] = PathWiseVega (S0, S, sigma, K, r, T)
        deltaLikelihoodV [idx] = LikelihoodDelta (S0, S, K, r, T, sigma)
    
    plt.figure (1)
    plt.grid ()
    plt.plot (NoOfPathsV, deltaPathWiseV, '.-r')
    plt.plot (NoOfPathsV, deltaLikelihoodV, '-b')
    plt.plot (NoOfPathsV, delta_Exact * np.ones ([len (NoOfPathsV), 1]))
    plt.xlabel ('number of paths')
    plt.ylabel ('Delta')
    plt.title ('Convergence of pathwise delta w.r.t. number of paths')
    plt.legend (['pathwise est', 'likelihood est', 'exact'])
    
    plt.figure (2)
    plt.grid ()
    plt.plot (NoOfPathsV, vegaPathWiseV, '.-r')
    plt.plot (NoOfPathsV, vegaLikelihoodV, '-b')
    plt.plot (NoOfPathsV, vega_Exact * np.ones ([len (NoOfPathsV), 1]))
    plt.xlabel ('number of paths')
    plt.ylabel ('Vega')
    plt.title ('Convergence of pathwise vega w.r.t. number of paths')
    plt.legend (['pathwise est', 'likelihood est', 'exact'])
    
    # Delta and Vega as a function of maturity
    T = 10.0
    NoOfSteps = 1000
    paths = GeneratePathsGBMEuler (25000, NoOfSteps, T, r, sigma, S0)
    S = paths ["S"]
    time = paths ["time"]
    
    deltaPathWiseV = np.zeros ([len (time), 1])
    deltaLikeliWiseV = np.zeros ([len (time), 1])
    vegaPathWiseV = np.zeros ([len (time), 1])
    vegaLikelihoodV = np.zeros ([len (time), 1])
    vegaExactV = np.zeros ([len (time), 1])
    deltaExactV = np.zeros ([len (time), 1])
    
    for (i, T) in enumerate (time):
        if i == 0:
            continue 
        S_t = S [:, :i+1]
        
        # Delta - - pathwise
        deltaPathWiseV [i] = PathwiseDelta (S0, S_t, K, r, T)
        deltaLikeliWiseV [i] = LikelihoodDelta (S0, S_t, K, r, T, sigma)
        deltaExactV [i]= BS_Delta (CP, S0, K, sigma, t, T, r)
        
        # Vega -- pathwise
        vegaPathWiseV [i] = PathwiseVega (S0, S_t, sigma, K, r, T)
        vegaLikelihoodV [i] = LikelihoodVega (S0, S_t, K, r, T, sigma)
        vega_Exact = BS_Vega (S0, K, sigma, t, T, r)
        vegaExactV [i] = vega_Exact
    plt.figure (3)
    plt.grid ()
    plt.plot (time, deltaExactV)
    plt.plot (time, deltaPathWiseV)
    plt.plot (time, deltaLikeliWiseV)
    plt.legend (['Exact', 'Pathwise Est', ' Likelihood est'])
    plt.title ('Estimation of Delta')
    plt.xlabel ('Time')
    plt.ylabel ("Delta")
    
    plt.figure (4)
    plt.grid ()
    plt.plot (time, vegaExactV, 1.5)
    plt.plot (time, vegaPathWiseV, 1.5)
    plt.plot (time, vegaLikelihoodV, 1.5)
    plt.legend (['Exact', 'Pathwise est', 'Likelihood est'])
    plt.title ('Estimation of Vega')
    plt.xlabel ('Time')
    plt.ylabel ('Vega')
    
mainCalculation ()
# Out:
# Running simulation with 50.0 paths
# Running simulation with 574.0 paths
# Running simulation with 1097.0 paths
# Running simulation with 1621.0 paths
# Running simulation with 2145.0 paths
# Running simulation with 2668.0 paths
# Running simulation with 3192.0 paths
# Running simulation with 3716.0 paths
# Running simulation with 4239.0 paths
# Running simulation with 4763.0 paths
# Running simulation with 5287.0 paths
# Running simulation with 5811.0 paths
# Running simulation with 6334.0 paths
# Running simulation with 6858.0 paths
# Running simulation with 7382.0 paths
# Running simulation with 7905.0 paths
# Running simulation with 8429.0 paths
# Running simulation with 8953.0 paths
# Running simulation with 9476.0 paths
# Running simulation with 10000.0 paths

# %%
# The Heston model and pricing of forward start options
# import required libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
import enum
import scipy.optimize as optimize

# set i = imaginary number
i = complex (0.0, 1.0)

# this class defines puts and calls
class OptionType (enum.Enum):
    CALL = 1.0
    PUT = - 1.0
    
def CallPutOptionPriceCOSMthd_FrwdStart (cf, CP, r, T1, T2, K, N, L):
    # cf - Chrarcterictic function
    # CP - C for call amd P for put
    # S0 - initial stock price
    # r - interest rate (constant)
    # tau - time to maturity
    # K - list of strikes 
    # N - number of expansion terms
    # L - size of trunctation domain (typ.: L = 8 or L = 10)
    
    tau = T2 - T1
    
    # reshape K to become a column vector 
    if K is not np.array:
        K = np.array (K).reshape ([len (K), 1])
        
    # adjust strike price 
    K = K + 1.0
    
    # assigning i = sqrt (-1)
    i = complex (0.0, 1.0)
    x0 = np.log (1.0 / K)
    
    # truncation domain 
    a = 0.0 - L * np.sqrt (tau)
    b = 0.0 + L * np.sqrt (tau)
    
    # summation from k = 0 to k = N - 1 
    k = np.linspace (0, N - 1, N).reshape ([N, 1])
    u = k * np.pi / (b - a);
    
    # determine coefficients for put prices
    H_k = CallPutCoefficients(CP,a,b,k)
    mat = np.exp(i * np.outer((x0 - a) , u))
    temp = cf(u) * H_k
    temp[0] = 0.5 * temp[0]
    value = np.exp(-r * T2) * K * np.real(mat.dot(temp))
    return value

# Determine coefficients for put and call prices
def CallPutCoefficients(CP,a,b,k):
    if CP==OptionType.CALL:
        c = 0.0
        d = b
        coef = Chi_Psi(a,b,c,d,k)
        Chi_k = coef["chi"]
        Psi_k = coef["psi"]
        if a < b and b < 0.0:
            H_k = np.zeros([len(k),1])
        else:
            H_k = 2.0 / (b - a) * (Chi_k - Psi_k)
    elif CP==OptionType.PUT:
        c = a
        d = 0.0
        coef = Chi_Psi(a,b,c,d,k)
        Chi_k = coef["chi"]
        Psi_k = coef["psi"]
        H_k = 2.0 / (b - a) * (- Chi_k + Psi_k)
    return H_k

def Chi_Psi(a,b,c,d,k):
    psi = np.sin(k * np.pi * (d - a) / (b - a)) - np.sin(k * np.pi * (c - a)/(b - a))
    psi[1:] = psi[1:] * (b - a) / (k[1:] * np.pi)
    psi[0] = d - c
    chi = 1.0 / (1.0 + np.power((k * np.pi / (b - a)) , 2.0))
    expr1 = np.cos(k * np.pi * (d - a)/(b - a)) * np.exp(d) - np.cos(k * np.pi * (c - a) / (b - a)) * np.exp(c)
    expr2 = k * np.pi / (b - a) * np.sin(k * np.pi * (d - a) / (b - a)) - k * np.pi / (b - a) * np.sin(k * np.pi * (c - a) / (b - a)) * np.exp(c)
    chi = chi * (expr1 + expr2)
    value = {"chi":chi,"psi":psi }
    return value

# Forward start Black-Scholes option price
def BS_Call_Option_Price_FrwdStart(K,sigma,T1,T2,r):
    if K is list:
        K = np.array(K).reshape([len(K),1])
    K = K + 1.0
    tau = T2 - T1
    d1 = (np.log(1.0 / K) + (r + 0.5 * np.power(sigma,2.0))* tau) / (sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt(tau)
    value = np.exp(-r*T1) * st.norm.cdf(d1) - st.norm.cdf(d2) * K * np.exp(-r * T2)
    return value

# implied volatility for the forward start call option
def ImpliedVolatility_FrwdStart (marketPrice, K, T1, T2, r):
    # To dertermine initiasl volatility we define a grid for sigma
    # and interpolate on the inverse function
    sigmaGrid = np.linspace (0, 2, 200)
    optPriceGrid = BS_Call_Option_Price_FrwdStart (K, sigmaGrid, T1, T2, r)
    sigmaInitial = np.interp (marketPrice, optPriceGrid,sigmaGrid)
    print ("Initial volatility = {0}".format (sigmaInitial))
    
    # use already  determined input for the local-search (final tuning)
    func = lambda sigma: np.power (BS_Call_Option_Price_FrwdStart (K, sigma, T1, T2, r) - marketPrice, 1.0)
    impliedVol = optimize.newton (func, sigmaInitial, tol = 1e-15)
    print ("Final volatility = {0}".format (impliedVol))
    return impliedVol

def ChFHestonModelForwardStart (r, T1, T2, kappa, gamma, vbar, v0, rho):
    i = complex (0.0, 1.0)
    tau = T2 - T1
    D1 = lambda u: np.sqrt (np.power (kappa - gamma * rho * i * u, 2) + (u * u + i * u) * gamma * gamma)
    g = lambda u: (kappa - gamma * rho * i * u - D1 (u)) / (kappa - gamma * rho * i * u + D1 (u))
    C = lambda u: (1.0 - np.exp (- D1 (u) * tau)) / (gamma * gamma * (1.0 - g(u) * np.exp (D1(u) * tau))) * (kappa - gamma * rho * i * u - D1(u))
    
    # note that we exclude the term -r*tau, as the discounting is performed in the COS method
    A = lambda u: r * i * u * tau + kappa * vbar * tau / gamma / gamma * (kappa - gamma * rho * i * u - D1 (u))\
        - 2 * kappa * vbar / gamma / gamma * np.log ((1.0 - g(u) * np.exp (-D1(u) * tau)) / (1.0 - g(u)))
    c_bar = lambda t1,t2: gamma * gamma / (4.0*kappa) * (1.0 - np.exp (-kappa * (t2 - t1)))
    delta = 4.0 * kappa * vbar / gamma / gamma
    kappa_bar = lambda t1,t2: 4.0 * kappa * v0 * np.exp (-kappa * (t2 - t1)) / (gamma * gamma * (1.0 - np.exp (- kappa * (t2 - t1))))
    term1 = lambda u: A(u) + C(u) * c_bar (0.0, T1) * kappa_bar (0.0, T1) / (1.0 - 2.0 * C(u) * c_bar (0.0, T1))
    term2 = lambda u: np.power (1.0 / (1.0 - 2.0 * C(u) * c_bar (0.0, T1)), 0.5 * delta)
    cf = lambda u: np.exp (term1 (u)) * term2 (u)
    return cf                                                                            
                                                                                
def mainCalculation ():
    CP = OptionType.CALL
    r = 0.0
    TMat1 = [[1.0, 3.0], [2.0, 4.0], [3.0, 5.0], [4.0, 6.0]]
    TMat2 = [[1.0, 2.0], [1.0, 3.0], [1.0, 4.0], [1.0, 5.0]]                                                                               
    K = np.linspace (-0.4, 4.0, 50)                                                                            
    K = np.array (K).reshape ([len(K), 1])
    
    N = 500
    L = 10
                                                                          
    # Heston model parameters
    kappa = 0.6                                                                            
    gamma = 0.2                                                                            
    vbar = 0.1                                                                            
    rho = - 0.5
    v0 = 0.05                               
                                                                                
    plt.figure (1)                                                                            
    plt.grid ()                                                                            
    plt.xlabel ('strike, K')                                                                            
    plt.ylabel ('implied volatility')                                                                            
    legend = []
    for T_pair in TMat1:
        T1 = T_pair [0]                                                                      
        T2 = T_pair [1]                                                                      
        cf = ChFHestonModelForwardStart (r, T1, T2, kappa, gamma, vbar, v0, rho)                                                                      
        # Forward-start option by the COS method                                                                      
        valCOS = CallPutOptionPriceCOSMthd_FrwdStart (cf, CP, r, T1, T2, K, N, L)                                                                      
        # implied volatilities
        IV = np.zeros ([len (K), 1])  
        for idx in range(0,len(K)):
            IV[idx] = ImpliedVolatility_FrwdStart(valCOS[idx],K[idx],T1,T2,r)
        plt.plot(K,IV*100.0)
        legend.append('T1={0} & T2={1}'.format(T1,T2))
    plt.legend(legend)
    plt.figure(2)
    plt.grid()
    plt.xlabel('strike, K')
    plt.ylabel('implied volatility')
    legend = []
    for T_pair in TMat2:
        T1= T_pair[0]
        T2= T_pair[1]
        cf = ChFHestonModelForwardStart(r,T1,T2,kappa,gamma,vbar,v0,rho)
        # Forward-start option by the COS method
        valCOS = CallPutOptionPriceCOSMthd_FrwdStart(cf,CP,r,T1,T2,K,N,L)
        # Implied volatilities
        IV =np.zeros([len(K),1])
        for idx in range(0,len(K)):
            IV[idx] = ImpliedVolatility_FrwdStart(valCOS[idx],K[idx],T1,T2,r)
        plt.plot(K,IV*100.0)
        legend.append('T1={0} & T2={1}'.format(T1,T2))
    plt.legend(legend)
    
mainCalculation()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:94: RuntimeWarning: divide by zero encountered in true_divide
# Initial volatility = [0.3127978]
# Final volatility = [0.31281989]
# Initial volatility = [0.29451354]
# Final volatility = [0.29454052]
# Initial volatility = [0.27933915]
# Final volatility = [0.27934997]
# Initial volatility = [0.26722967]
# Final volatility = [0.26723436]
# Initial volatility = [0.25821836]
# Final volatility = [0.25821753]
# Initial volatility = [0.25231933]
# Final volatility = [0.25231905]
# Initial volatility = [0.24950604]
# Final volatility = [0.2495092]
# Initial volatility = [0.2496326]
# Final volatility = [0.24964131]
# Initial volatility = [0.25237243]
# Final volatility = [0.25238335]
# Initial volatility = [0.25716225]
# Final volatility = [0.25720305]
# Initial volatility = [0.26340732]
# Final volatility = [0.26344299]
# Initial volatility = [0.27043104]
# Final volatility = [0.27045367]
# Initial volatility = [0.27763489]
# Final volatility = [0.27770758]
# Initial volatility = [0.2847688]
# Final volatility = [0.28484578]
# Initial volatility = [0.2916565]
# Final volatility = [0.29166386]
# Initial volatility = [0.29797529]
# Final volatility = [0.2980703]
# Initial volatility = [0.30396146]
# Final volatility = [0.30404378]
# Initial volatility = [0.30952393]
# Final volatility = [0.30960094]
# Initial volatility = [0.31466758]
# Final volatility = [0.31477553]
# Initial volatility = [0.31951923]
# Final volatility = [0.31960665]
# Initial volatility = [0.32403027]
# Final volatility = [0.32413263]
# Initial volatility = [0.32825818]
# Final volatility = [0.32838838]
# Initial volatility = [0.33236456]
# Final volatility = [0.33240452]
# Initial volatility = [0.33605205]
# Final volatility = [0.33620735]
# Initial volatility = [0.33971648]
# Final volatility = [0.33981932]
# Initial volatility = [0.34317473]
# Final volatility = [0.34325957]
# Initial volatility = [0.3463714]
# Final volatility = [0.34654437]
# Initial volatility = [0.34956713]
# Final volatility = [0.3496877]
# Initial volatility = [0.35264187]
# Final volatility = [0.35270161]
# Initial volatility = [0.3554213]
# Final volatility = [0.35559659]
# Initial volatility = [0.35820567]
# Final volatility = [0.35838174]
# Initial volatility = [0.36100855]
# Final volatility = [0.36106512]
# Initial volatility = [0.36353735]
# Final volatility = [0.36365385]
# Initial volatility = [0.36595433]
# Final volatility = [0.36615428]
# Initial volatility = [0.36838441]
# Final volatility = [0.36857214]
# Initial volatility = [0.37083642]
# Final volatility = [0.37091254]
# Initial volatility = [0.37308507]
# Final volatility = [0.37318009]
# Initial volatility = [0.37518176]
# Final volatility = [0.37537904]
# Initial volatility = [0.37729129]
# Final volatility = [0.37751329]
# Initial volatility = [0.37941964]
# Final volatility = [0.37958636]
# Initial volatility = [0.38157251]
# Final volatility = [0.38160148]
# Initial volatility = [0.38343785]
# Final volatility = [0.3835616]
# Initial volatility = [0.3852561]
# Final volatility = [0.38546951]
# Initial volatility = [0.38708794]
# Final volatility = [0.38732785]
# Initial volatility = [0.38893729]
# Final volatility = [0.38913894]
# Initial volatility = [0.39080795]
# Final volatility = [0.39090496]
# Initial volatility = [0.39256918]
# Final volatility = [0.39262801]
# Initial volatility = [0.3941349]
# Final volatility = [0.39430995]
# Initial volatility = [0.39571161]
# Final volatility = [0.39595267]
# Initial volatility = [0.39730203]
# Final volatility = [0.39755788]
# Initial volatility = [0.3231231]
# Final volatility = [0.32314672]
# Initial volatility = [0.30450589]
# Final volatility = [0.30452983]
# Initial volatility = [0.28897688]
# Final volatility = [0.28898779]
# Initial volatility = [0.27657859]
# Final volatility = [0.27658269]
# Initial volatility = [0.26740686]
# Final volatility = [0.2674058]
# Initial volatility = [0.26151611]
# Final volatility = [0.26151604]
# Initial volatility = [0.25888051]
# Final volatility = [0.25888391]
# Initial volatility = [0.25931266]
# Final volatility = [0.2593216]
# Initial volatility = [0.26241542]
# Final volatility = [0.26242498]
# Initial volatility = [0.26754878]
# Final volatility = [0.2675838]
# Initial volatility = [0.2740474]
# Final volatility = [0.27408488]
# Initial volatility = [0.28125471]
# Final volatility = [0.2812583]
# Initial volatility = [0.28852826]
# Final volatility = [0.28858528]
# Initial volatility = [0.29565451]
# Final volatility = [0.29572956]
# Initial volatility = [0.30248144]
# Final volatility = [0.30251108]
# Initial volatility = [0.30878334]
# Final volatility = [0.30885813]
# Initial volatility = [0.31467746]
# Final volatility = [0.3147633]
# Initial volatility = [0.32020002]
# Final volatility = [0.32025191]
# Initial volatility = [0.32525713]
# Final volatility = [0.32536261]
# Initial volatility = [0.33007293]
# Final volatility = [0.33013688]
# Initial volatility = [0.33451083]
# Final volatility = [0.33461386]
# Initial volatility = [0.33871783]
# Final volatility = [0.33882835]
# Initial volatility = [0.34275848]
# Final volatility = [0.34281041]
# Initial volatility = [0.34644242]
# Final volatility = [0.34658559]
# Initial volatility = [0.35009379]
# Final volatility = [0.35017549]
# Initial volatility = [0.35350925]
# Final volatility = [0.35359844]
# Initial volatility = [0.35671124]
# Final volatility = [0.35687002]
# Initial volatility = [0.35990404]
# Final volatility = [0.36000354]
# Initial volatility = [0.36294241]
# Final volatility = [0.36301049]
# Initial volatility = [0.36573604]
# Final volatility = [0.36590088]
# Initial volatility = [0.36852783]
# Final volatility = [0.36868343]
# Initial volatility = [0.37133047]
# Final volatility = [0.37136585]
# Initial volatility = [0.37383664]
# Final volatility = [0.37395499]
# Initial volatility = [0.37627058]
# Final volatility = [0.37645696]
# Initial volatility = [0.3787118]
# Final volatility = [0.37887731]
# Initial volatility = [0.38116859]
# Final volatility = [0.38122098]
# Initial volatility = [0.3833903]
# Final volatility = [0.38349246]
# Initial volatility = [0.38550775]
# Final volatility = [0.38569589]
# Initial volatility = [0.38763345]
# Final volatility = [0.38783506]
# Initial volatility = [0.38977303]
# Final volatility = [0.38991343]
# Initial volatility = [0.39193186]
# Final volatility = [0.39193415]
# Initial volatility = [0.39377003]
# Final volatility = [0.39390015]
# Initial volatility = [0.39560979]
# Final volatility = [0.39581415]
# Initial volatility = [0.39745952]
# Final volatility = [0.39767875]
# Initial volatility = [0.39932292]
# Final volatility = [0.39949624]
# Initial volatility = [0.40120357]
# Final volatility = [0.40126879]
# Initial volatility = [0.40292034]
# Final volatility = [0.40299847]
# Initial volatility = [0.40450974]
# Final volatility = [0.40468712]
# Initial volatility = [0.40610744]
# Final volatility = [0.40633661]
# Initial volatility = [0.40771603]
# Final volatility = [0.40794862]
# Initial volatility = [0.32858009]
# Final volatility = [0.3286181]
# Initial volatility = [0.30985396]
# Final volatility = [0.30986963]
# Initial volatility = [0.29416802]
# Final volatility = [0.29417849]
# Initial volatility = [0.28164434]
# Final volatility = [0.28164467]
# Initial volatility = [0.27239569]
# Final volatility = [0.27239525]
# Initial volatility = [0.26651185]
# Final volatility = [0.26651093]
# Initial volatility = [0.26395979]
# Final volatility = [0.26396292]
# Initial volatility = [0.26453097]
# Final volatility = [0.26454195]
# Initial volatility = [0.26778567]
# Final volatility = [0.26780736]
# Initial volatility = [0.27309191]
# Final volatility = [0.2731113]
# Initial volatility = [0.2796897]
# Final volatility = [0.27971584]
# Initial volatility = [0.28688922]
# Final volatility = [0.2869442]
# Initial volatility = [0.2942329]
# Final volatility = [0.29428402]
# Initial volatility = [0.30140831]
# Final volatility = [0.3014112]
# Initial volatility = [0.30808435]
# Final volatility = [0.30815769]
# Initial volatility = [0.31439011]
# Final volatility = [0.31446119]
# Initial volatility = [0.32027668]
# Final volatility = [0.32032065]
# Initial volatility = [0.32566712]
# Final volatility = [0.3257652]
# Initial volatility = [0.33080165]
# Final volatility = [0.3308355]
# Initial volatility = [0.33546606]
# Final volatility = [0.33557389]
# Initial volatility = [0.33995018]
# Final volatility = [0.34001965]
# Initial volatility = [0.34411527]
# Final volatility = [0.34420737]
# Initial volatility = [0.34804411]
# Final volatility = [0.34816669]
# Initial volatility = [0.35191428]
# Final volatility = [0.35192268]
# Initial volatility = [0.35536536]
# Final volatility = [0.35549647]
# Initial volatility = [0.3587827]
# Final volatility = [0.35890595]
# Initial volatility = [0.36214637]
# Final volatility = [0.36216627]
# Initial volatility = [0.36515097]
# Final volatility = [0.36529041]
# Initial volatility = [0.36814023]
# Final volatility = [0.36828957]
# Initial volatility = [0.3711297]
# Final volatility = [0.37117351]
# Initial volatility = [0.37384242]
# Final volatility = [0.37395073]
# Initial volatility = [0.37645654]
# Final volatility = [0.37662877]
# Initial volatility = [0.37907206]
# Final volatility = [0.37921433]
# Initial volatility = [0.38169887]
# Final volatility = [0.38171341]
# Initial volatility = [0.38400795]
# Final volatility = [0.38413145]
# Initial volatility = [0.3862878]
# Final volatility = [0.38647331]
# Initial volatility = [0.38857364]
# Final volatility = [0.3887434]
# Initial volatility = [0.39087211]
# Final volatility = [0.39094582]
# Initial volatility = [0.39300867]
# Final volatility = [0.39308429]
# Initial volatility = [0.39499078]
# Final volatility = [0.39516224]
# Initial volatility = [0.39697838]
# Final volatility = [0.39718278]
# Initial volatility = [0.39897602]
# Final volatility = [0.39914882]
# Initial volatility = [0.40098805]
# Final volatility = [0.40106305]
# Initial volatility = [0.40286027]
# Final volatility = [0.40292803]
# Initial volatility = [0.40457906]
# Final volatility = [0.40474606]
# Initial volatility = [0.40630413]
# Final volatility = [0.40651928]
# Initial volatility = [0.40803858]
# Final volatility = [0.40824974]
# Initial volatility = [0.4097853]
# Final volatility = [0.40993928]
# Initial volatility = [0.41154722]
# Final volatility = [0.41158974]
# Initial volatility = [0.41311432]
# Final volatility = [0.41320282]
# Initial volatility = [0.33156586]
# Final volatility = [0.33156746]
# Initial volatility = [0.31274954]
# Final volatility = [0.31276038]
# Initial volatility = [0.2969859]
# Final volatility = [0.29699889]
# Initial volatility = [0.2843996]
# Final volatility = [0.28440253]
# Initial volatility = [0.27511864]
# Final volatility = [0.2751175]
# Initial volatility = [0.26923703]
# Final volatility = [0.26923641]
# Initial volatility = [0.26672702]
# Final volatility = [0.26673095]
# Initial volatility = [0.26736867]
# Final volatility = [0.26738056]
# Initial volatility = [0.27071991]
# Final volatility = [0.27072544]
# Initial volatility = [0.27606537]
# Final volatility = [0.27609859]
# Initial volatility = [0.28273038]
# Final volatility = [0.28275005]
# Initial volatility = [0.28997286]
# Final volatility = [0.29000022]
# Initial volatility = [0.29727963]
# Final volatility = [0.29734067]
# Initial volatility = [0.30439625]
# Final volatility = [0.30445375]
# Initial volatility = [0.31116581]
# Final volatility = [0.31117769]
# Initial volatility = [0.3173713]
# Final volatility = [0.31745495]
# Initial volatility = [0.32323761]
# Final volatility = [0.32328763]
# Initial volatility = [0.32862294]
# Final volatility = [0.3287067]
# Initial volatility = [0.33368598]
# Final volatility = [0.3337538]
# Initial volatility = [0.33837261]
# Final volatility = [0.3384716]
# Initial volatility = [0.34285203]
# Final volatility = [0.3428994]
# Initial volatility = [0.34694883]
# Final volatility = [0.34707164]
# Initial volatility = [0.35098118]
# Final volatility = [0.35101769]
# Initial volatility = [0.35465244]
# Final volatility = [0.35476236]
# Initial volatility = [0.3581991]
# Final volatility = [0.3583265]
# Initial volatility = [0.36172294]
# Final volatility = [0.36172776]
# Initial volatility = [0.3648553]
# Final volatility = [0.36498108]
# Initial volatility = [0.36795452]
# Final volatility = [0.36809925]
# Initial volatility = [0.3710472]
# Final volatility = [0.3710933]
# Initial volatility = [0.37386871]
# Final volatility = [0.37397286]
# Initial volatility = [0.37658135]
# Final volatility = [0.37674632]
# Initial volatility = [0.37929178]
# Final volatility = [0.37942113]
# Initial volatility = [0.38199776]
# Final volatility = [0.3820039]
# Initial volatility = [0.38436847]
# Final volatility = [0.38450058]
# Initial volatility = [0.38673617]
# Final volatility = [0.38691654]
# Initial volatility = [0.38910852]
# Final volatility = [0.38925661]
# Initial volatility = [0.39149266]
# Final volatility = [0.39152516]
# Initial volatility = [0.39361936]
# Final volatility = [0.39372625]
# Initial volatility = [0.39568151]
# Final volatility = [0.39586359]
# Initial volatility = [0.39774884]
# Final volatility = [0.39794056]
# Initial volatility = [0.39982628]
# Final volatility = [0.39996028]
# Initial volatility = [0.4019185]
# Final volatility = [0.40192562]
# Initial volatility = [0.40372066]
# Final volatility = [0.40383928]
# Initial volatility = [0.40551241]
# Final volatility = [0.40570379]
# Initial volatility = [0.40731086]
# Final volatility = [0.40752144]
# Initial volatility = [0.40911929]
# Final volatility = [0.40929436]
# Initial volatility = [0.4109409]
# Final volatility = [0.4110246]
# Initial volatility = [0.41266302]
# Final volatility = [0.41271399]
# Initial volatility = [0.414212]
# Final volatility = [0.41436437]
# Initial volatility = [0.41576647]
# Final volatility = [0.41597741]
# Initial volatility = [0.33350957]
# Final volatility = [0.33356206]
# Initial volatility = [0.30595405]
# Final volatility = [0.30601296]
# Initial volatility = [0.28206622]
# Final volatility = [0.28207436]
# Initial volatility = [0.26228528]
# Final volatility = [0.26228967]
# Initial volatility = [0.24827788]
# Final volatility = [0.24827845]
# Initial volatility = [0.24250118]
# Final volatility = [0.24250171]
# Initial volatility = [0.2462889]
# Final volatility = [0.2463024]
# Initial volatility = [0.25711885]
# Final volatility = [0.25714883]
# Initial volatility = [0.27006236]
# Final volatility = [0.27008437]
# Initial volatility = [0.28201762]
# Final volatility = [0.28203222]
# Initial volatility = [0.29237632]
# Final volatility = [0.29240313]
# Initial volatility = [0.30151718]
# Final volatility = [0.30151755]
# Initial volatility = [0.3096594]
# Final volatility = [0.30972863]
# Initial volatility = [0.3171313]
# Final volatility = [0.31725704]
# Initial volatility = [0.32412276]
# Final volatility = [0.32422886]
# Initial volatility = [0.33066891]
# Final volatility = [0.33072308]
# Initial volatility = [0.33663121]
# Final volatility = [0.33679742]
# Initial volatility = [0.34244801]
# Final volatility = [0.3424972]
# Initial volatility = [0.34768118]
# Final volatility = [0.34786264]
# Initial volatility = [0.35284771]
# Final volatility = [0.35292621]
# Initial volatility = [0.35751481]
# Final volatility = [0.35771901]
# Initial volatility = [0.36222861]
# Final volatility = [0.36226462]
# Initial volatility = [0.36636101]
# Final volatility = [0.36658786]
# Initial volatility = [0.37060499]
# Final volatility = [0.37070575]
# Initial volatility = [0.37444658]
# Final volatility = [0.37463767]
# Initial volatility = [0.37816355]
# Final volatility = [0.3783981]
# Initial volatility = [0.38199009]
# Final volatility = [0.38199875]
# Initial volatility = [0.3852152]
# Final volatility = [0.38545608]
# Initial volatility = [0.38853091]
# Final volatility = [0.38877522]
# Initial volatility = [0.39196793]
# Final volatility = [0.39196889]
# Initial volatility = [0.39480793]
# Final volatility = [0.39504839]
# Initial volatility = [0.39772645]
# Final volatility = [0.39801372]
# Initial volatility = [0.40075125]
# Final volatility = [0.40087839]
# Initial volatility = [0.40349003]
# Final volatility = [0.40365129]
# Initial volatility = [0.40602258]
# Final volatility = [0.40632763]
# Initial volatility = [0.40863759]
# Final volatility = [0.40891954]
# Initial volatility = [0.41135915]
# Final volatility = [0.41143931]
# Initial volatility = [0.41369014]
# Final volatility = [0.41387792]
# Initial volatility = [0.41591622]
# Final volatility = [0.41623899]
# Initial volatility = [0.41822383]
# Final volatility = [0.41854268]
# Initial volatility = [0.42061898]
# Final volatility = [0.42078591]
# Initial volatility = [0.42285307]
# Final volatility = [0.42295509]
# Initial volatility = [0.42477862]
# Final volatility = [0.42506551]
# Initial volatility = [0.42677689]
# Final volatility = [0.42713714]
# Initial volatility = [0.42884155]
# Final volatility = [0.42915634]
# Initial volatility = [0.43095968]
# Final volatility = [0.43110662]
# Initial volatility = [0.4328998]
# Final volatility = [0.43300851]
# Initial volatility = [0.43459839]
# Final volatility = [0.43488722]
# Initial volatility = [0.43635141]
# Final volatility = [0.43672731]
# Initial volatility = [0.43813472]
# Final volatility = [0.43850101]
# Initial volatility = [0.3127978]
# Final volatility = [0.31281989]
# Initial volatility = [0.29451354]
# Final volatility = [0.29454052]
# Initial volatility = [0.27933915]
# Final volatility = [0.27934997]
# Initial volatility = [0.26722967]
# Final volatility = [0.26723436]
# Initial volatility = [0.25821836]
# Final volatility = [0.25821753]
# Initial volatility = [0.25231933]
# Final volatility = [0.25231905]
# Initial volatility = [0.24950604]
# Final volatility = [0.2495092]
# Initial volatility = [0.2496326]
# Final volatility = [0.24964131]
# Initial volatility = [0.25237243]
# Final volatility = [0.25238335]
# Initial volatility = [0.25716225]
# Final volatility = [0.25720305]
# Initial volatility = [0.26340732]
# Final volatility = [0.26344299]
# Initial volatility = [0.27043104]
# Final volatility = [0.27045367]
# Initial volatility = [0.27763489]
# Final volatility = [0.27770758]
# Initial volatility = [0.2847688]
# Final volatility = [0.28484578]
# Initial volatility = [0.2916565]
# Final volatility = [0.29166386]
# Initial volatility = [0.29797529]
# Final volatility = [0.2980703]
# Initial volatility = [0.30396146]
# Final volatility = [0.30404378]
# Initial volatility = [0.30952393]
# Final volatility = [0.30960094]
# Initial volatility = [0.31466758]
# Final volatility = [0.31477553]
# Initial volatility = [0.31951923]
# Final volatility = [0.31960665]
# Initial volatility = [0.32403027]
# Final volatility = [0.32413263]
# Initial volatility = [0.32825818]
# Final volatility = [0.32838838]
# Initial volatility = [0.33236456]
# Final volatility = [0.33240452]
# Initial volatility = [0.33605205]
# Final volatility = [0.33620735]
# Initial volatility = [0.33971648]
# Final volatility = [0.33981932]
# Initial volatility = [0.34317473]
# Final volatility = [0.34325957]
# Initial volatility = [0.3463714]
# Final volatility = [0.34654437]
# Initial volatility = [0.34956713]
# Final volatility = [0.3496877]
# Initial volatility = [0.35264187]
# Final volatility = [0.35270161]
# Initial volatility = [0.3554213]
# Final volatility = [0.35559659]
# Initial volatility = [0.35820567]
# Final volatility = [0.35838174]
# Initial volatility = [0.36100855]
# Final volatility = [0.36106512]
# Initial volatility = [0.36353735]
# Final volatility = [0.36365385]
# Initial volatility = [0.36595433]
# Final volatility = [0.36615428]
# Initial volatility = [0.36838441]
# Final volatility = [0.36857214]
# Initial volatility = [0.37083642]
# Final volatility = [0.37091254]
# Initial volatility = [0.37308507]
# Final volatility = [0.37318009]
# Initial volatility = [0.37518176]
# Final volatility = [0.37537904]
# Initial volatility = [0.37729129]
# Final volatility = [0.37751329]
# Initial volatility = [0.37941964]
# Final volatility = [0.37958636]
# Initial volatility = [0.38157251]
# Final volatility = [0.38160148]
# Initial volatility = [0.38343785]
# Final volatility = [0.3835616]
# Initial volatility = [0.3852561]
# Final volatility = [0.38546951]
# Initial volatility = [0.38708794]
# Final volatility = [0.38732785]
# Initial volatility = [0.38893729]
# Final volatility = [0.38913894]
# Initial volatility = [0.39080795]
# Final volatility = [0.39090496]
# Initial volatility = [0.39256918]
# Final volatility = [0.39262801]
# Initial volatility = [0.3941349]
# Final volatility = [0.39430995]
# Initial volatility = [0.39571161]
# Final volatility = [0.39595267]
# Initial volatility = [0.39730203]
# Final volatility = [0.39755788]
# Initial volatility = [0.30452057]
# Final volatility = [0.30455048]
# Initial volatility = [0.29094518]
# Final volatility = [0.29094934]
# Initial volatility = [0.27995714]
# Final volatility = [0.27996186]
# Initial volatility = [0.271213]
# Final volatility = [0.2712131]
# Initial volatility = [0.26441689]
# Final volatility = [0.26441507]
# Initial volatility = [0.25935102]
# Final volatility = [0.25934984]
# Initial volatility = [0.25584985]
# Final volatility = [0.25585164]
# Initial volatility = [0.25378226]
# Final volatility = [0.2537885]
# Initial volatility = [0.25303501]
# Final volatility = [0.25304491]
# Initial volatility = [0.25348769]
# Final volatility = [0.25350657]
# Initial volatility = [0.25501278]
# Final volatility = [0.25504903]
# Initial volatility = [0.25748427]
# Final volatility = [0.25753197]
# Initial volatility = [0.26078772]
# Final volatility = [0.26079994]
# Initial volatility = [0.26462645]
# Final volatility = [0.26468896]
# Initial volatility = [0.26897806]
# Final volatility = [0.26903663]
# Initial volatility = [0.27363071]
# Final volatility = [0.27369223]
# Initial volatility = [0.27844441]
# Final volatility = [0.27852461]
# Initial volatility = [0.2833623]
# Final volatility = [0.28342622]
# Initial volatility = [0.28821882]
# Final volatility = [0.28831388]
# Initial volatility = [0.29306552]
# Final volatility = [0.29312655]
# Initial volatility = [0.29771033]
# Final volatility = [0.29782219]
# Initial volatility = [0.30233655]
# Final volatility = [0.30237384]
# Initial volatility = [0.30663859]
# Final volatility = [0.30676617]
# Initial volatility = [0.31096279]
# Final volatility = [0.31099204]
# Initial volatility = [0.31492975]
# Final volatility = [0.31505052]
# Initial volatility = [0.31883348]
# Final volatility = [0.31894422]
# Initial volatility = [0.32262686]
# Final volatility = [0.32267887]
# Initial volatility = [0.3261172]
# Final volatility = [0.32626117]
# Initial volatility = [0.3296029]
# Final volatility = [0.32969903]
# Initial volatility = [0.33293291]
# Final volatility = [0.33300041]
# Initial volatility = [0.33602148]
# Final volatility = [0.33617329]
# Initial volatility = [0.33910566]
# Final volatility = [0.33922552]
# Initial volatility = [0.34213809]
# Final volatility = [0.34216449]
# Initial volatility = [0.34485688]
# Final volatility = [0.34499718]
# Initial volatility = [0.34757047]
# Final volatility = [0.34773027]
# Initial volatility = [0.35028734]
# Final volatility = [0.35036999]
# Initial volatility = [0.35285494]
# Final volatility = [0.35292161]
# Initial volatility = [0.35523431]
# Final volatility = [0.35539056]
# Initial volatility = [0.35761324]
# Final volatility = [0.35778203]
# Initial volatility = [0.35999692]
# Final volatility = [0.36009984]
# Initial volatility = [0.36231381]
# Final volatility = [0.36234838]
# Initial volatility = [0.36439266]
# Final volatility = [0.36453171]
# Initial volatility = [0.36647146]
# Final volatility = [0.36665311]
# Initial volatility = [0.36855451]
# Final volatility = [0.368716]
# Initial volatility = [0.37064507]
# Final volatility = [0.37072285]
# Initial volatility = [0.37262349]
# Final volatility = [0.37267731]
# Initial volatility = [0.37443497]
# Final volatility = [0.37458131]
# Initial volatility = [0.37624854]
# Final volatility = [0.37643765]
# Initial volatility = [0.37806673]
# Final volatility = [0.37824833]
# Initial volatility = [0.37989192]
# Final volatility = [0.38001524]
# Initial volatility = [0.29933242]
# Final volatility = [0.29935104]
# Initial volatility = [0.28882731]
# Final volatility = [0.28883868]
# Initial volatility = [0.28040923]
# Final volatility = [0.28041124]
# Initial volatility = [0.27363504]
# Final volatility = [0.27363468]
# Initial volatility = [0.26820787]
# Final volatility = [0.26820522]
# Initial volatility = [0.26390938]
# Final volatility = [0.2639071]
# Initial volatility = [0.26058486]
# Final volatility = [0.26058482]
# Initial volatility = [0.2581194]
# Final volatility = [0.25812343]
# Initial volatility = [0.2564248]
# Final volatility = [0.25643588]
# Initial volatility = [0.25543571]
# Final volatility = [0.25545401]
# Initial volatility = [0.25509481]
# Final volatility = [0.25512086]
# Initial volatility = [0.25535037]
# Final volatility = [0.25538616]
# Initial volatility = [0.2561552]
# Final volatility = [0.25620216]
# Initial volatility = [0.25746756]
# Final volatility = [0.25752147]
# Initial volatility = [0.25925161]
# Final volatility = [0.25929525]
# Initial volatility = [0.2614674]
# Final volatility = [0.26147203]
# Initial volatility = [0.26393468]
# Final volatility = [0.26399865]
# Initial volatility = [0.26673078]
# Final volatility = [0.2668216]
# Initial volatility = [0.26983616]
# Final volatility = [0.26988711]
# Initial volatility = [0.27308488]
# Final volatility = [0.2731441]
# Initial volatility = [0.27643441]
# Final volatility = [0.27654494]
# Initial volatility = [0.27999041]
# Final volatility = [0.28004668]
# Initial volatility = [0.28352995]
# Final volatility = [0.28360988]
# Initial volatility = [0.2870818]
# Final volatility = [0.28720426]
# Initial volatility = [0.29076755]
# Final volatility = [0.29080036]
# Initial volatility = [0.29426979]
# Final volatility = [0.29437584]
# Initial volatility = [0.29778901]
# Final volatility = [0.29791454]
# Initial volatility = [0.30139517]
# Final volatility = [0.30140123]
# Initial volatility = [0.30470394]
# Final volatility = [0.30482555]
# Initial volatility = [0.30805185]
# Final volatility = [0.30818106]
# Initial volatility = [0.31145505]
# Final volatility = [0.31146087]
# Initial volatility = [0.31454053]
# Final volatility = [0.3146632]
# Initial volatility = [0.31764378]
# Final volatility = [0.31778549]
# Initial volatility = [0.32078322]
# Final volatility = [0.32082821]
# Initial volatility = [0.32369022]
# Final volatility = [0.32379056]
# Initial volatility = [0.32652108]
# Final volatility = [0.32667469]
# Initial volatility = [0.32937216]
# Final volatility = [0.32948064]
# Initial volatility = [0.33218095]
# Final volatility = [0.3322121]
# Initial volatility = [0.33473418]
# Final volatility = [0.33486902]
# Initial volatility = [0.3372989]
# Final volatility = [0.33745572]
# Initial volatility = [0.33987931]
# Final volatility = [0.33997426]
# Initial volatility = [0.34238335]
# Final volatility = [0.34242435]
# Initial volatility = [0.34467618]
# Final volatility = [0.34481274]
# Initial volatility = [0.34697821]
# Final volatility = [0.3471421]
# Initial volatility = [0.34928768]
# Final volatility = [0.34940955]
# Initial volatility = [0.3516092]
# Final volatility = [0.35161883]
# Initial volatility = [0.35367265]
# Final volatility = [0.35377702]
# Initial volatility = [0.35571947]
# Final volatility = [0.35588121]
# Initial volatility = [0.35777341]
# Final volatility = [0.35793612]
# Initial volatility = [0.35983599]
# Final volatility = [0.35994269]

# %%
# This class defines puts and calls 
class OptionType (enum.Enum):
    CALL = 1.0
    PUT = -1.0
    
def CallPutOptionPriceCosMthd (cf, CP, S0, r, tau, K, N, L):
    # cf - characteristic function
    # CP - C for call and P for put
    # S0 - inital stock price
    # r - interest rate 
    # tau - time to maturity
    # K -list of strikes
    # N - number of expansion terms
    # L - size of truncation domain (typ.: L=8 or L=10)
    
    # reshape K to become a column vector
    if K is not np.array: 
        K = np.array (K).reshape ([len(K), 1])
        
    # assigning i = sqrt (-1)
    i = np.complex (0.0, 1.0)
    x0 = np.log (S0 / K)
    
    # truncation domain
    a = 0.0 - L * np.sqrt (tau)
    b = 0.0 + L * np.sqrt (tau)
    
    # summation from k = 0 to k = N - 1
    k = np.linspace (0, N-1, N).reshape ([N, 1])
    u = k * np.pi / (b - a)
    
    # determine coefficients for put prices
    H_k = CallPutCoefficients (CP, a, b, k)
    mat = np.exp (i * np.outer ((x0 - a), u))
    temp = cf (u) * H_k 
    temp[0] = 0.5 * temp [0]
    value = np.exp (-r * tau) * K * np.real (mat.dot (temp))
    return value
    
# determine coefficients for put prices
def CallPutCoefficients (CP, a, b, k):
    if CP == OptionType.CALL:
        c = 0.0
        d = b
        coef = Chi_Psi (a, b, c, d, k)
        Chi_k = coef ["chi"]
        Psi_k = coef ["psi"]
        if a < b and b < 0.0:
            H_k = np.zeros ([len(k), 1])
        else:
            H_k = 2.0 / (b - a) * (Chi_k - Psi_k)
    elif CP == OptionType.PUT:
        c = a
        d = 0.0
        coef = Chi_Psi (a, b, c, d, k)
        Chi_k = coef ["chi"]
        Psi_k = coef ["psi"]
        H_k = 2.0 / (b - a) * (-Chi_k + Psi_k)
        
    return H_k

def Chi_Psi (a, b, c, d, k):
    psi = np.sin (k * np.pi * (d - a) / (b - a)) - np.sin (k * np.sin (k * np.pi * (c - a) / (b - a)))
    psi[1:] = psi[1:] * (b - a) / (k[1:] * np.pi)
    psi[0] = d - c
    
    chi = 1.0 / (1.0 + np.power ((k * np.pi / (b - a)), 2.0))
    expr1 = np.cos (k * np.pi * (d - a)/(b - a)) * np.exp (d) - np.cos (k * np.pi * (c - a) / (b - a)) * np.exp (c)
    expr2 = k * np.pi / (b - a) * np.sin (k * np.pi * (d - a) / (b - a)) - k * np.pi / (b - a) * np.sin (l * np.pi * (c - a) / (b - a)) * np.exp (c)
    chi = chi * (expr1 + expr2)
    value = {"chi":chi, "psi":psi}
    return value

# Black-Scholes call option price
def BS_Call_Put_Option_Price (CP, S_0, K, sigma, tau, r):
    if K is list:
        K = np.array (K).reshape ([len(K), 1])
    d1 = (np.log (S_0 / K) + (r + 0.5 * np.power (sigma, 2.0))*tau) / (sigma * np.sqrt(tau))
    d2 = d1 - sigma * np.sqrt (tau)
    if CP == OptionType.CALL:
        value = st.norm.cdf (d1) * S_0 - st.norm.cdf (d2) * K * np.exp (-r * tau)
    elif CP == OptionType.PUT:
        value = st.norm.cdf (-d2) * K * np.exp(-r * tau) - st.norm.cdf (-d1) * S_0
    return value
